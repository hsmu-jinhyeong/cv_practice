# %% [markdown]
# # 예제 1 : 우편번호 인식기 v2
# - 1.1. LeNet 재현
# - 1.2. 우편번호 인식기 v2 구현

# %% [markdown]
# ## 1.1 : LeNet 재현

# %% [markdown]
# ### 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dropout,Dense,Input
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### 데이터 준비

# %%
(x_train,y_train),(x_test,y_test)=ds.mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0

# %%
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

# %% [markdown]
# ### 모델 정의

# %%
cnn=Sequential()
input = Input(shape=(28,28,1))
cnn.add(input)
cnn.add(Conv2D(6,(5,5),padding='same',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2),strides=2))
cnn.add(Conv2D(16,(5,5),padding='valid',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2),strides=2))
cnn.add(Conv2D(120,(5,5),padding='valid',activation='relu'))
cnn.add(Flatten())
cnn.add(Dense(units=84,activation='relu'))
cnn.add(Dense(units=10,activation='softmax'))

# %% [markdown]
# ### 학습 및 평가

# %%
cnn.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
cnn.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)
# Out:
# Epoch 1/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8948 - loss: 0.3471 - val_accuracy: 0.9716 - val_loss: 0.0919
# Epoch 2/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9747 - loss: 0.0808 - val_accuracy: 0.9838 - val_loss: 0.0534
# Epoch 3/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9822 - loss: 0.0572 - val_accuracy: 0.9831 - val_loss: 0.0538
# Epoch 4/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9863 - loss: 0.0448 - val_accuracy: 0.9878 - val_loss: 0.0392
# Epoch 5/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9881 - loss: 0.0382 - val_accuracy: 0.9878 - val_loss: 0.0365
# Epoch 6/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9903 - loss: 0.0315 - val_accuracy: 0.9863 - val_loss: 0.0395
# Epoch 7/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9916 - loss: 0.0273 - val_accuracy: 0.9879 - val_loss: 0.0377
# Epoch 8/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9916 - loss: 0.0255 - val_accuracy: 0.9879 - val_loss: 0.0373
# Epoch 9/30
# 469/469 - 3s - 5ms/step - accuracy: 0.9931 - loss: 0.0209 - val_accuracy: 0.9881 - val_loss: 0.0344
# Epoch 10/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9939 - loss: 0.0185 - val_accuracy: 0.9892 - val_loss: 0.0387
# Epoch 11/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9944 - loss: 0.0165 - val_accuracy: 0.9879 - val_loss: 0.0419
# Epoch 12/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9949 - loss: 0.0146 - val_accuracy: 0.9883 - val_loss: 0.0366
# Epoch 13/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.9891 - val_loss: 0.0324
# Epoch 14/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9961 - loss: 0.0123 - val_accuracy: 0.9902 - val_loss: 0.0328
# Epoch 15/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9961 - loss: 0.0117 - val_accuracy: 0.9897 - val_loss: 0.0353
# Epoch 16/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9963 - loss: 0.0110 - val_accuracy: 0.9899 - val_loss: 0.0377
# Epoch 17/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9961 - loss: 0.0112 - val_accuracy: 0.9882 - val_loss: 0.0410
# Epoch 18/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9972 - loss: 0.0081 - val_accuracy: 0.9858 - val_loss: 0.0520
# Epoch 19/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9970 - loss: 0.0091 - val_accuracy: 0.9911 - val_loss: 0.0360
# Epoch 20/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9979 - loss: 0.0063 - val_accuracy: 0.9906 - val_loss: 0.0411
# Epoch 21/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9974 - loss: 0.0078 - val_accuracy: 0.9892 - val_loss: 0.0394
# Epoch 22/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9976 - loss: 0.0069 - val_accuracy: 0.9880 - val_loss: 0.0496
# Epoch 23/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9914 - val_loss: 0.0348
# Epoch 24/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9982 - loss: 0.0056 - val_accuracy: 0.9921 - val_loss: 0.0359
# Epoch 25/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9980 - loss: 0.0053 - val_accuracy: 0.9852 - val_loss: 0.0701
# Epoch 26/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9977 - loss: 0.0070 - val_accuracy: 0.9901 - val_loss: 0.0434
# Epoch 27/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9882 - val_loss: 0.0614
# Epoch 28/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9983 - loss: 0.0052 - val_accuracy: 0.9846 - val_loss: 0.0730
# Epoch 29/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9905 - val_loss: 0.0413
# Epoch 30/30
# 469/469 - 3s - 6ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9907 - val_loss: 0.0461

# %%
res=cnn.evaluate(x_test,y_test,verbose=0)
print('정확도=',res[1]*100)
# Out:
# 정확도= 99.07000064849854

# %% [markdown]
# ### 모델 저장

# %%
cnn.save('cnn_v2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 1.2. : 우편번호 인식기 v2 구현

# %% [markdown]
# ### 라이브러리 불러오기

# %%
## 라이브러리 불러오기
import numpy as np
import tensorflow as tf
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# ### 저장한 모델 불러오기
#
# - `LeNet` 재현 실습을 통해 저장한 모델 불러오기
# - MNIST 데이터셋으로 학습된 손글씨 숫자 인식 모델

# %%
model = tf.keras.models.load_model('cnn_v2.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### 초기화 함수 정의
# - 우편번호 작성 화면 초기화
# - 5개의 숫자를 작성할 수 있는 영역 생성, 안내 텍스트 표시

# %%
def reset():
    global img
    img = np.ones((200, 520, 3), dtype=np.uint8) * 255
    for i in range(5):
        cv.rectangle(img, (10 + i * 100, 50), (10 + (i + 1) * 100, 150), (0, 0, 255))
    cv.putText(img, 'e:erase s:show r:recognition q:quit', (10, 40), cv.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 1)

# %% [markdown]
# ### 숫자 추출 함수 정의
# - 작성된 숫자를 추출하여 모델이 처리할 수 있는 형태로 변환
# - 각 숫자는 28x28 크기로 리사이즈, 흑백으로 변환

# %%
def grab_numerals():
    numerals = []
    for i in range(5):
        roi = img[51:149, 11 + i * 100:9 + (i + 1) * 100, 0]
        roi = 255 - cv.resize(roi, (28, 28), interpolation=cv.INTER_CUBIC)
        numerals.append(roi)
    numerals = np.array(numerals)
    return numerals

# %% [markdown]
# ### 숫자 시각화 함수 정의
#
# - 추출된 숫자를 화면에 표시
# - 사용자가 작성한 숫자 확인 가능

# %%
def show():
    numerals = grab_numerals()
    plt.figure(figsize=(25, 5))
    for i in range(5):
        plt.subplot(1, 5, i + 1)
        plt.imshow(numerals[i], cmap='gray')
        plt.xticks([]); plt.yticks([])
    plt.show()

# %% [markdown]
# ### 숫자 인식 함수 정의
# - 추출된 숫자를 모델에 입력하여 예측
# - 예측된 숫자는 화면에 표시되고 소리를 재생함

# %%
def recognition():
    numerals = grab_numerals()
    numerals = numerals.reshape(5, 28, 28) # 지난 실습 7-7.ipynb (5, 784)에서 (5, 28, 28) 로 변경
    numerals = numerals.astype(np.float32) / 255.0
    res = model.predict(numerals)  # 신경망 모델로 예측
    class_id = np.argmax(res, axis=1)
    for i in range(5):
        cv.putText(img, str(class_id[i]), (50 + i * 100, 180), cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 1)
    # winsound.Beep(1000, 500)

# %% [markdown]
# ### 마우스 이벤트 처리
#
# - 왼쪽 버튼을 클릭하거나 드래그하면 숫자를 작성할 수 있음

# %%
BrushSiz = 4
LColor = (0, 0, 0)

def writing(event, x, y, flags, param):
    if event == cv.EVENT_LBUTTONDOWN:
        cv.circle(img, (x, y), BrushSiz, LColor, -1)
    elif event == cv.EVENT_MOUSEMOVE and flags == cv.EVENT_FLAG_LBUTTON:
        cv.circle(img, (x, y), BrushSiz, LColor, -1)

# %% [markdown]
# ### 메인 루프
#
# - 사용자는 'e', 's', 'r', 'q' 키를 사용하여 초기화, 시각화, 인식, 종료를 수행함

# %%
reset()
cv.namedWindow('Writing')
cv.setMouseCallback('Writing', writing)

while True:
    cv.imshow('Writing', img)
    key = cv.waitKey(1)
    if key == ord('e'):
        reset()
    elif key == ord('s'):
        show()
    elif key == ord('r'):
        recognition()
    elif key == ord('q'):
        break

cv.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
